# %% [markdown]
# #**Importing the libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ##**1.reading the dataset**

# %%
data=pd.read_csv('cars_data.csv')

# %%
data.head()
# Out:
#      Make    Model    Nickname  ... 5-yr Depreciation Top Speed  0-60 Time
# 0  Suzuki   Vitara  Philippine  ...              0.13     200.9       11.5
# 1   Honda    S2000      Henrik  ...              0.02     158.5        8.8
# 2     BMW       Z4      Lebbie  ...              0.24     149.5       14.4
# 3  Toyota   Tacoma    Jefferey  ...              0.20     153.3       11.5
# 4    Ford  Festiva     Glendon  ...              0.18     122.0       14.9
#
# [5 rows x 20 columns]

# %% [markdown]
# ##**2. Check for the null values present in the dataset**.

# %%
data.isna().sum()
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# there is no null values

# %% [markdown]
# ##**3.Plot a bar graph of male vs female buyers participated in the sales.**

# %%
data['Buyer Gender'].count()
# Out:
# 10000

# %%
data.groupby('Buyer Gender')

# %%
data
# Out:
#          Make        Model    Nickname  ... 5-yr Depreciation Top Speed  0-60 Time
# 0      Suzuki       Vitara  Philippine  ...              0.13     200.9       11.5
# 1       Honda        S2000      Henrik  ...              0.02     158.5        8.8
# 2         BMW           Z4      Lebbie  ...              0.24     149.5       14.4
# 3      Toyota       Tacoma    Jefferey  ...              0.20     153.3       11.5
# 4        Ford      Festiva     Glendon  ...              0.18     122.0       14.9
# ...       ...          ...         ...  ...               ...       ...        ...
# 9995    Mazda      Tribute      Cooper  ...              0.14     245.8        8.0
# 9996      GMC  Sierra 2500         Dud  ...              0.11     147.4       12.3
# 9997  Mercury      Mariner     Chariot  ...              0.12     198.1       11.8
# 9998   Daewoo      Leganza       Dynah  ...              0.04     206.7       12.2
# ...

# %% [markdown]
# ##**3.Plot a bar graph of male vs female buyers participated in the sales.**

# %%
buyers=data['Buyer Gender']

# %%
y=buyers.value_counts()

# %%
y.plot(kind='bar',figsize=(10,10))
plt.title('male vs female buyers participated')
plt.xlabel('Gender')
plt.ylabel('No of Male & Female')
# Out:
# Text(0, 0.5, 'No of Male & Female')

# %%
car=data[['Make','Model','Sale Price','Resell Price']]
car
# Out:
#          Make        Model  Sale Price  Resell Price
# 0      Suzuki       Vitara    54806.14      33858.32
# 1       Honda        S2000    51826.30       2989.28
# 2         BMW           Z4    82929.14      35049.16
# 3      Toyota       Tacoma    56928.66       8236.15
# 4        Ford      Festiva    77201.26      32765.76
# ...       ...          ...         ...           ...
# 9995    Mazda      Tribute    58580.65      42640.82
# 9996      GMC  Sierra 2500    75229.74      21115.58
# 9997  Mercury      Mariner    34755.44       2731.25
# 9998   Daewoo      Leganza    98725.42      18718.58
# 9999   Toyota      Sequoia    96769.78       4545.95
#
# [10000 rows x 4 columns]

# %% [markdown]
# ##**4.Find the top 5 cars based on their sales price.**

# %%
car.nlargest(n=5, columns=['Sale Price'])
# Out:
#             Make      Model  Sale Price  Resell Price
# 5984  Volkswagen  Jetta III    99997.65      31601.95
# 1270        Audi         A6    99991.91      34711.19
# 3460       Lexus         LX    99983.38      21462.44
# 9032       Mazda       MX-6    99978.17      45958.19
# 302        Lexus         ES    99973.44      32521.53

# %% [markdown]
# ##**5.Find the least 5 cars based on their Resell price.**

# %%
car.nsmallest(n=5, columns=['Resell Price'])
# Out:
#             Make        Model  Sale Price  Resell Price
# 2446   Chevrolet         1500    49909.44       2000.84
# 4933         GMC  Savana 1500    80084.82       2005.44
# 566       Jaguar           XF    24124.99       2014.09
# 2538  Mitsubishi       3000GT    88195.95       2017.24
# 5869    Infiniti          G37    77791.65       2017.83
