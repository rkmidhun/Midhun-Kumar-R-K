# %% [markdown]
# importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1.Read dataset

# %%
data=pd.read_excel('iris.xls')

# %% [markdown]
# 2.Dislay Dataset

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# displaying colums heads

# %%
for col in data.columns:
  print(col)
# Out:
# SL
# SW
# PL
# PW
# Classification

# %%
clasification=[]
clasification=data['Classification']
clas=[]
for i in clasification:
  if i not in clas:
    clas.append(i)
clas
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %% [markdown]
# 3.Calculating Mean of each colums

# %%
data.mean(axis=0)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# 4.Checking Null Values

# %%
data.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
x_axis=[]
x_axis=data.columns
x_axis
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
x=x_axis.drop("Classification")
x
# Out:
# Index(['SL', 'SW', 'PL', 'PW'], dtype='object')

# %%
y_axis=[]
y_axis=data.mean(axis=0)
y_axis
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
plt.plot(x,y_axis)
plt.title("mean")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %% [markdown]
# Filter by claification

# %%
df=data[data['Classification']=="Iris-setosa"]
df
# Out:
#      SL   SW   PL   PW Classification
# 0   5.1  3.5  1.4  0.2    Iris-setosa
# 1   4.9  3.0  1.4  0.2    Iris-setosa
# 2   4.7  3.2  1.3  0.2    Iris-setosa
# 3   4.6  3.1  1.5  0.2    Iris-setosa
# 4   5.0  3.6  1.4  0.2    Iris-setosa
# 5   5.4  3.9  1.7  0.4    Iris-setosa
# 6   4.6  3.4  1.4  0.3    Iris-setosa
# 7   5.0  3.4  1.5  0.2    Iris-setosa
# 8   4.4  2.9  1.4  0.2    Iris-setosa
# 9   4.9  3.1  1.5  0.1    Iris-setosa
# 10  5.4  3.7  1.5  0.2    Iris-setosa
# 11  4.8  3.4  1.6  0.2    Iris-setosa
# 12  4.8  3.0  1.4  0.1    Iris-setosa
# 13  4.3  3.0  1.1  0.1    Iris-setosa
# 14  5.8  4.0  1.2  0.2    Iris-setosa
# 15  5.7  4.4  1.5  0.4    Iris-setosa
# 16  5.4  3.9  1.3  0.4    Iris-setosa
# 17  5.1  3.5  1.4  0.3    Iris-setosa
# 18  5.7  3.8  1.7  0.3    Iris-setosa
# 19  5.1  3.8  1.5  0.3    Iris-setosa
# 20  5.4  3.4  1.7  0.2    Iris-setosa
# 21  5.1  3.7  1.5  0.4    Iris-setosa
# 22  4.6  3.6  1.0  0.2    Iris-setosa
# 23  5.1  3.3  1.7  0.5    Iris-setosa
# ...

# %%
df.mean()
# Out:
# SL    5.006
# SW    3.418
# PL    1.464
# PW    0.244
# dtype: float64

# %%
df_y=[]
df_y=df.mean()
df_y
# Out:
# SL    5.006
# SW    3.418
# PL    1.464
# PW    0.244
# dtype: float64

# %%
df_x=[]
df_x=df.columns
df_x.drop("Classification")
# Out:
# Index(['SL', 'SW', 'PL', 'PW'], dtype='object')

# %% [markdown]
# Graph Showing average of iris-setosa

# %%
plt.plot(df_x,df_y)
plt.title("iris-setosa")
plt.show()

# %%
df1=data[data['Classification']=="Iris-versicolor"]
df1
# Out:
#      SL   SW   PL   PW   Classification
# 50  7.0  3.2  4.7  1.4  Iris-versicolor
# 51  6.4  3.2  4.5  1.5  Iris-versicolor
# 52  6.9  3.1  4.9  1.5  Iris-versicolor
# 53  5.5  2.3  4.0  1.3  Iris-versicolor
# 54  6.5  2.8  4.6  1.5  Iris-versicolor
# 55  5.7  2.8  4.5  1.3  Iris-versicolor
# 56  6.3  3.3  4.7  1.6  Iris-versicolor
# 57  4.9  2.4  3.3  1.0  Iris-versicolor
# 58  6.6  2.9  4.6  1.3  Iris-versicolor
# 59  5.2  2.7  3.9  1.4  Iris-versicolor
# 60  5.0  2.0  3.5  1.0  Iris-versicolor
# 61  5.9  3.0  4.2  1.5  Iris-versicolor
# 62  6.0  2.2  4.0  1.0  Iris-versicolor
# 63  6.1  2.9  4.7  1.4  Iris-versicolor
# 64  5.6  2.9  3.6  1.3  Iris-versicolor
# 65  6.7  3.1  4.4  1.4  Iris-versicolor
# 66  5.6  3.0  4.5  1.5  Iris-versicolor
# 67  5.8  2.7  4.1  1.0  Iris-versicolor
# 68  6.2  2.2  4.5  1.5  Iris-versicolor
# 69  5.6  2.5  3.9  1.1  Iris-versicolor
# 70  5.9  3.2  4.8  1.8  Iris-versicolor
# 71  6.1  2.8  4.0  1.3  Iris-versicolor
# ...

# %%
df1.mean()
# Out:
# SL    5.936
# SW    2.770
# PL    4.260
# PW    1.326
# dtype: float64

# %%
xaxis=[]
xaxis=df1.columns
xaxis=xaxis.drop("Classification")
xaxis
# Out:
# Index(['SL', 'SW', 'PL', 'PW'], dtype='object')

# %%
yaxis=[]
yaxis=df1.mean(axis=0)
yaxis
# Out:
# SL    5.936
# SW    2.770
# PL    4.260
# PW    1.326
# dtype: float64

# %% [markdown]
# Graph Showing average of Iris-versicolor

# %%
plt.plot(xaxis,yaxis)
plt.title("Iris-versicolor")
plt.show()

# %%
df2=data[data['Classification']=="Iris-virginica"]
df2
# Out:
#       SL   SW   PL   PW  Classification
# 100  6.3  3.3  6.0  2.5  Iris-virginica
# 101  5.8  2.7  5.1  1.9  Iris-virginica
# 102  7.1  3.0  5.9  2.1  Iris-virginica
# 103  6.3  2.9  5.6  1.8  Iris-virginica
# 104  6.5  3.0  5.8  2.2  Iris-virginica
# 105  7.6  3.0  6.6  2.1  Iris-virginica
# 106  4.9  2.5  4.5  1.7  Iris-virginica
# 107  7.3  2.9  6.3  1.8  Iris-virginica
# 108  6.7  2.5  5.8  1.8  Iris-virginica
# 109  7.2  3.6  6.1  2.5  Iris-virginica
# 110  6.5  3.2  5.1  2.0  Iris-virginica
# 111  6.4  2.7  5.3  1.9  Iris-virginica
# 112  6.8  3.0  5.5  2.1  Iris-virginica
# 113  5.7  2.5  5.0  2.0  Iris-virginica
# 114  5.8  2.8  5.1  2.4  Iris-virginica
# 115  6.4  3.2  5.3  2.3  Iris-virginica
# 116  6.5  3.0  5.5  1.8  Iris-virginica
# 117  7.7  3.8  6.7  2.2  Iris-virginica
# 118  7.7  2.6  6.9  2.3  Iris-virginica
# 119  6.0  2.2  5.0  1.5  Iris-virginica
# 120  6.9  3.2  5.7  2.3  Iris-virginica
# 121  5.6  2.8  4.9  2.0  Iris-virginica
# ...

# %%
df2.mean()
# Out:
# SL    6.588
# SW    2.974
# PL    5.552
# PW    2.026
# dtype: float64

# %%
df2_x=[]
df2_x=df2.columns
df2_x=df2_x.drop("Classification")
df2_x
# Out:
# Index(['SL', 'SW', 'PL', 'PW'], dtype='object')

# %%
df2_y=[]
df2_y=df2.mean(axis=0)
df2_y
# Out:
# SL    6.588
# SW    2.974
# PL    5.552
# PW    2.026
# dtype: float64

# %%
plt.plot(df2_x,df2_y)
plt.title("Iris-virginica")
plt.show()
